# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# !pip install matplotlib

# %%
x = np.array([12, 23, 30, 35, 41, 47])
y = np.array([15, 21, 29, 38, 45, 58])
z = np.array([54, 46, 41, 33, 29, 10])

# %%
# line plot

# %%
plt.title("line plot")
plt.xlabel("x value")
plt.ylabel("y value")

plt.plot(x, y, marker = "o", mfc = "red");
plt.grid()
# markers -> #, *, o, >, <, ^, H

# %%
# bar chart

# %%
courses = ["dart", "lua", "python", "assembly", "C#"]
students = [56, 52, 65, 30, 40]

# %%
plt.barh(courses, students)
plt.grid()

# %%
# scatter

# %%
plt.scatter(x, y);

# %%
# PIE

# %%
plt.pie(students, labels = courses, autopct = "%.2f%%",
       shadow = True);#, *, o, >, <, ^
